# %%
import pandas as pd
import numpy as np

# %%
data=pd.DataFrame(np.random.rand(50,5))

# %%
data
# Out:
#            0         1         2         3         4
# 0   0.958235  0.027597  0.262607  0.800500  0.618106
# 1   0.467871  0.373971  0.238836  0.468697  0.498178
# 2   0.665277  0.174673  0.270980  0.883553  0.376069
# 3   0.395012  0.906119  0.170114  0.193875  0.810198
# 4   0.176825  0.400916  0.374824  0.542250  0.196873
# 5   0.471207  0.041226  0.411815  0.786563  0.709155
# 6   0.617748  0.021895  0.634162  0.091900  0.192595
# 7   0.201632  0.201931  0.632052  0.416307  0.445001
# 8   0.872152  0.401260  0.749877  0.593635  0.277293
# 9   0.293963  0.755061  0.225984  0.967660  0.810201
# 10  0.445751  0.386094  0.148655  0.465793  0.665738
# 11  0.208506  0.935458  0.432672  0.683061  0.803847
# 12  0.912004  0.746904  0.570851  0.288025  0.087505
# 13  0.334347  0.261949  0.737494  0.764244  0.173918
# 14  0.834958  0.401676  0.177991  0.646866  0.464910
# 15  0.275177  0.416872  0.998126  0.272740  0.530473
# 16  0.278406  0.510225  0.856588  0.606164  0.690647
# ...

# %%
#note the first digit mark the columns and the second digit marks the index or rows this is just when calling
data[4][10]='idrees chnge'

# %%
data
# Out:
#            0         1         2         3             4
# 0   0.958235  0.027597  0.262607  0.800500      0.618106
# 1   0.467871  0.373971  0.238836  0.468697      0.498178
# 2   0.665277  0.174673  0.270980  0.883553      0.376069
# 3   0.395012  0.906119  0.170114  0.193875      0.810198
# 4   0.176825  0.400916  0.374824  0.542250      0.196873
# 5   0.471207  0.041226  0.411815  0.786563      0.709155
# 6   0.617748  0.021895  0.634162  0.091900      0.192595
# 7   0.201632  0.201931  0.632052  0.416307      0.445001
# 8   0.872152  0.401260  0.749877  0.593635      0.277293
# 9   0.293963  0.755061  0.225984  0.967660      0.810201
# 10  0.445751  0.386094  0.148655  0.465793  idrees chnge
# 11  0.208506  0.935458  0.432672  0.683061      0.803847
# 12  0.912004  0.746904  0.570851  0.288025      0.087505
# 13  0.334347  0.261949  0.737494  0.764244      0.173918
# 14  0.834958  0.401676  0.177991  0.646866       0.46491
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#           0         1         2         3         4
# 0  0.958235  0.027597  0.262607  0.800500  0.618106
# 1  0.467871  0.373971  0.238836  0.468697  0.498178
# 2  0.665277  0.174673  0.270980  0.883553  0.376069
# 3  0.395012  0.906119  0.170114  0.193875  0.810198
# 4  0.176825  0.400916  0.374824  0.542250  0.196873

# %%
#the data 2 varibale will make view of data
data2=data

# %%
#as you can see i have make change in data 2 and it automaticaly have chnged in data
data2[0][0]='idrees khan'
# Out:
# C:\Users\Idris Khan\AppData\Local\Temp\ipykernel_6480\1955828788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[0][0]='idrees khan'

# %%
#if you make changes in data 2 it will automatically chnge values in data
data.head()
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1     0.467871  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data2.head()
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1     0.467871  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data[0][1]='khan khan'
data.head()
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data2.head()
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
#this is a copy command it will just copy all the data from the other variable
data3=data2.copy()

# %%
data3.head()
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data3[2][1]='chnges in data 3'
# Out:
# C:\Users\Idris Khan\AppData\Local\Temp\ipykernel_6480\3067757199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[2][1]='chnges in data 3'

# %%
#i have make chnges in data 3
data3.head()
# Out:
#              0         1                 2         3         4
# 0  idrees khan  0.027597          0.262607  0.800500  0.618106
# 1    khan khan  0.373971  chnges in data 3  0.468697  0.498178
# 2     0.665277  0.174673           0.27098  0.883553  0.376069
# 3     0.395012  0.906119          0.170114  0.193875  0.810198
# 4     0.176825  0.400916          0.374824  0.542250  0.196873

# %%
#look there has not been any chnge in data
data2.head()
#sometime the copy command dosent work pandas itself decide if it will copy or view so for that purpose we use loc function
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data.head(2)
# Out:
#              0         1         2         3         4
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178

# %%
data.loc[0,0]='idrees khattak'
data.head(2)
# Out:
#                 0         1         2         3         4
# 0  idrees khattak  0.027597  0.262607  0.800500  0.618106
# 1       khan khan  0.373971  0.238836  0.468697  0.498178

# %%
data.columns=list("ABCDE")
data.head(2)
# Out:
#                 A         B         C         D         E
# 0  idrees khattak  0.027597  0.262607  0.800500  0.618106
# 1       khan khan  0.373971  0.238836  0.468697  0.498178

# %%
#so you have to specify the column and row by its own name while using loc funcion or it will make another column
data.loc[0,0]='chnges'
data.head(2)
# Out:
#                 A         B         C         D         E       0
# 0  idrees khattak  0.027597  0.262607  0.800500  0.618106  chnges
# 1       khan khan  0.373971  0.238836  0.468697  0.498178     NaN

# %%
#axis=0 is used for row and axis=1 is used for column
data=data.drop(0, axis=1)
data.head(2)
# Out:
#                 A         B         C         D         E
# 0  idrees khattak  0.027597  0.262607  0.800500  0.618106
# 1       khan khan  0.373971  0.238836  0.468697  0.498178

# %%
#this will chnge idrees khattak to idrees khan
data.loc[0,'A']='idrees khan'
data.head()
# Out:
#              A         B         C         D         E
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673  0.270980  0.883553  0.376069
# 3     0.395012  0.906119  0.170114  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
#calling specific column and row by loc funtion
data.loc[[3,4],['B','E']]
# Out:
#           B         E
# 3  0.906119  0.810198
# 4  0.400916  0.196873

# %%
data.loc[[3,4]]
# Out:
#           A         B         C         D         E
# 3  0.395012  0.906119  0.170114  0.193875  0.810198
# 4  0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data.loc[3,'C']='khan'
data.head()
# Out:
#              A         B         C         D         E (3, C)
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106   khan
# 1    khan khan  0.373971  0.238836  0.468697  0.498178   khan
# 2     0.665277  0.174673   0.27098  0.883553  0.376069   khan
# 3     0.395012  0.906119      khan  0.193875  0.810198   khan
# 4     0.176825  0.400916  0.374824  0.542250  0.196873   khan

# %%
data=data.drop((3,'C'),axis=1)
data.head()
# Out:
#              A         B         C         D         E
# 0  idrees khan  0.027597  0.262607  0.800500  0.618106
# 1    khan khan  0.373971  0.238836  0.468697  0.498178
# 2     0.665277  0.174673   0.27098  0.883553  0.376069
# 3     0.395012  0.906119      khan  0.193875  0.810198
# 4     0.176825  0.400916  0.374824  0.542250  0.196873

# %%
data=data.loc[:,['A','D']]
data.head()
# Out:
#              A         D
# 0  idrees khan  0.800500
# 1    khan khan  0.468697
# 2     0.665277  0.883553
# 3     0.395012  0.193875
# 4     0.176825  0.542250

# %%
data.head(1)
# Out:
#           A         D
# 3  0.395012  0.193875

# %%
#using condition ins pandas
data=data.loc[(data['D']<0.3)]
data
# Out:
#            A         D
# 3   0.395012  0.193875
# 6   0.617748  0.091900
# 12  0.912004  0.288025
# 15  0.275177  0.272740
# 21   0.81054  0.211908
# 23   0.73284  0.226566
# 26  0.657785  0.058511
# 28  0.973334  0.098100
# 29  0.348907  0.158507
# 31  0.475497  0.177668
# 32  0.270762  0.243461
# 34  0.871602  0.189638
# 43  0.710601  0.217234
# 44  0.822601  0.036600

# %%
#there is another function like loc that is iloc..in loc function we will have to call cloumns and rows by there specific name
#but in iloc that is not hte condition you just hacve to use numbers whie calling a row and column

# %%
data.iloc[0,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 data.iloc[0,4]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1066, in _LocationIndexer.__getitem__(self, key)
#    1064     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065     if self._is_scalar_access(key):
# -> 1066         return self.obj._get_value(*key, takeable=self._takeable)
#    1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3914, in DataFrame._get_value(self, index, col, takeable)
#    3895 """
#    3896 Quickly retrieve single value at passed column and index.
#    3897
#    (...)
#    3911 `self.columns._index_as_unique`; Caller is responsible for checking.
# ...
